# %%
# reduce memory usage of each week's dataframe and pickle. In the future, we will only be reading from these pickled files
# alternatively, we also have CSV's
import pandas as pd
import numpy as np
weeks_dict = dict()
for i in range(1, 9):
    headers = [*pd.read_csv(f'week{i}_clean.csv', nrows=1)]
    weeks_dict[i] = pd.read_csv(f'week{i}_clean.csv', usecols =[i for i in headers if i != 'time'])
    #reduce memory usage
    weeks_dict[i]['gameId'] = weeks_dict[i]['gameId'].fillna(0).astype('uint32', errors = 'ignore')
    weeks_dict[i]['nflId'] = weeks_dict[i]['nflId'].fillna(0).astype('uint32', errors = 'ignore')
    weeks_dict[i]['playId'] = weeks_dict[i]['playId'].fillna(0).astype('uint16', errors = 'ignore')
    weeks_dict[i]['frameId'] = weeks_dict[i]['frameId'].fillna(0).astype('uint8', errors = 'ignore')
    weeks_dict[i]['jerseyNumber'] = weeks_dict[i]['jerseyNumber'].fillna(-1).astype('int8', errors = 'ignore')
    weeks_dict[i]['team'] = weeks_dict[i]['team'].astype('category', errors = 'ignore')
    weeks_dict[i]['playDirection'] = weeks_dict[i]['playDirection'].astype('category', errors = 'ignore')
    weeks_dict[i][weeks_dict[i].select_dtypes(np.float64).columns] = weeks_dict[i].select_dtypes(np.float64).astype(np.float32)
    weeks_dict[i]['event'] = weeks_dict[i]['event'].astype('category', errors = 'ignore')
    print(weeks_dict[i].info(memory_usage='deep'))
    
    # create pickle
    weeks_dict[i].to_pickle(f'week{i}_clean_pickled.pkl')

games = pd.read_csv("games.csv")
pff = pd.read_csv("pffScoutingData.csv")
pff['gameId'] = pff['gameId'].fillna(-1).astype('uint32', errors = 'ignore')
pff['nflId'] = pff['nflId'].fillna(-1).astype('uint32', errors = 'ignore')
pff['playId'] = pff['playId'].fillna(-1).astype('uint16', errors = 'ignore')
pff['pff_role'] = pff['pff_role'].astype('category')
pff['pff_positionLinedUp'] = pff['pff_positionLinedUp'].astype('category')
pff['pff_hit'] = pff['pff_hit'].fillna(0).astype('int8')
pff['pff_hurry'] = pff['pff_hurry'].fillna(0).astype('int8')
pff['pff_sack'] = pff['pff_sack'].fillna(0).astype('int8')
pff['pff_beatenByDefender'] = pff['pff_beatenByDefender'].fillna(0).astype('int8')
pff['pff_hitAllowed'] = pff['pff_hitAllowed'].fillna(0).astype('int8')
pff['pff_hurryAllowed'] = pff['pff_hurryAllowed'].fillna(0).astype('int8')
pff['pff_sackAllowed'] = pff['pff_sackAllowed'].fillna(0).astype('int8')
pff['pff_nflIdBlockedPlayer'] = pff['pff_nflIdBlockedPlayer'].fillna(0).astype('uint32')
pff['pff_blockType'] = pff['pff_blockType'].astype('category')
pff['pff_backFieldBlock'] = pff['pff_backFieldBlock'].fillna(0).astype('int8')
pff.to_pickle(f'pff_pickled.pkl')

players = pd.read_csv("players.csv")
play = pd.read_csv("plays.csv")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 843295 entries, 0 to 843294
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         843295 non-null  uint32
#  1   playId         843295 non-null  uint16
#  2   nflId          843295 non-null  uint32
#  3   jerseyNumber   843295 non-null  int8
#  4   team           843295 non-null  category
#  5   playDirection  843295 non-null  category
#  6   x              843295 non-null  float32
#  7   y              843295 non-null  float32
#  8   s              843295 non-null  float32
#  9   a              843295 non-null  float32
#  10  dis            843295 non-null  float32
#  11  o              806630 non-null  float32
#  12  dir            806630 non-null  float32
#  13  event          843295 non-null  category
#  14  frameId        843295 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 34.6 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 792235 entries, 0 to 792234
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         792235 non-null  uint32
#  1   playId         792235 non-null  uint16
#  2   nflId          792235 non-null  uint32
#  3   jerseyNumber   792235 non-null  int8
#  4   team           792235 non-null  category
#  5   playDirection  792235 non-null  category
#  6   x              792235 non-null  float32
#  7   y              792235 non-null  float32
#  8   s              792235 non-null  float32
#  9   a              792235 non-null  float32
#  10  dis            792235 non-null  float32
#  11  o              757790 non-null  float32
#  12  dir            757790 non-null  float32
#  13  event          792235 non-null  category
#  14  frameId        792235 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 32.5 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 857762 entries, 0 to 857761
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         857762 non-null  uint32
#  1   playId         857762 non-null  uint16
#  2   nflId          857762 non-null  uint32
#  3   jerseyNumber   857762 non-null  int8
#  4   team           857762 non-null  category
#  5   playDirection  857762 non-null  category
#  6   x              857762 non-null  float32
#  7   y              857762 non-null  float32
#  8   s              857762 non-null  float32
#  9   a              857762 non-null  float32
#  10  dis            857762 non-null  float32
#  11  o              820468 non-null  float32
#  12  dir            820468 non-null  float32
#  13  event          857762 non-null  category
#  14  frameId        857762 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 35.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 815281 entries, 0 to 815280
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         815281 non-null  uint32
#  1   playId         815281 non-null  uint16
#  2   nflId          815281 non-null  uint32
#  3   jerseyNumber   815281 non-null  int8
#  4   team           815281 non-null  category
#  5   playDirection  815281 non-null  category
#  6   x              815281 non-null  float32
#  7   y              815281 non-null  float32
#  8   s              815281 non-null  float32
#  9   a              815281 non-null  float32
#  10  dis            815281 non-null  float32
#  11  o              779834 non-null  float32
#  12  dir            779834 non-null  float32
#  13  event          815281 non-null  category
#  14  frameId        815281 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 33.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 840075 entries, 0 to 840074
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         840075 non-null  uint32
#  1   playId         840075 non-null  uint16
#  2   nflId          840075 non-null  uint32
#  3   jerseyNumber   840075 non-null  int8
#  4   team           840075 non-null  category
#  5   playDirection  840075 non-null  category
#  6   x              840075 non-null  float32
#  7   y              840075 non-null  float32
#  8   s              840075 non-null  float32
#  9   a              840075 non-null  float32
#  10  dis            840075 non-null  float32
#  11  o              803550 non-null  float32
#  12  dir            803550 non-null  float32
#  13  event          840075 non-null  category
#  14  frameId        840075 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 34.5 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 741474 entries, 0 to 741473
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         741474 non-null  uint32
#  1   playId         741474 non-null  uint16
#  2   nflId          741474 non-null  uint32
#  3   jerseyNumber   741474 non-null  int8
#  4   team           741474 non-null  category
#  5   playDirection  741474 non-null  category
#  6   x              741474 non-null  float32
#  7   y              741474 non-null  float32
#  8   s              741474 non-null  float32
#  9   a              741474 non-null  float32
#  10  dis            741474 non-null  float32
#  11  o              709236 non-null  float32
#  12  dir            709236 non-null  float32
#  13  event          741474 non-null  category
#  14  frameId        741474 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 30.4 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 688022 entries, 0 to 688021
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         688022 non-null  uint32
#  1   playId         688022 non-null  uint16
#  2   nflId          688022 non-null  uint32
#  3   jerseyNumber   688022 non-null  int8
#  4   team           688022 non-null  category
#  5   playDirection  688022 non-null  category
#  6   x              688022 non-null  float32
#  7   y              688022 non-null  float32
#  8   s              688022 non-null  float32
#  9   a              688022 non-null  float32
#  10  dis            688022 non-null  float32
#  11  o              658108 non-null  float32
#  12  dir            658108 non-null  float32
#  13  event          688022 non-null  category
#  14  frameId        688022 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 28.2 MB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 738553 entries, 0 to 738552
# Data columns (total 15 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   gameId         738553 non-null  uint32
#  1   playId         738553 non-null  uint16
#  2   nflId          738553 non-null  uint32
#  3   jerseyNumber   738553 non-null  int8
#  4   team           738553 non-null  category
#  5   playDirection  738553 non-null  category
#  6   x              738553 non-null  float32
#  7   y              738553 non-null  float32
#  8   s              738553 non-null  float32
#  9   a              738553 non-null  float32
#  10  dis            738553 non-null  float32
#  11  o              706442 non-null  float32
#  12  dir            706442 non-null  float32
#  13  event          738553 non-null  category
#  14  frameId        738553 non-null  uint8
# dtypes: category(3), float32(7), int8(1), uint16(1), uint32(2), uint8(1)
# memory usage: 30.3 MB
# None

# %%
pff.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188254 entries, 0 to 188253
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   gameId                  188254 non-null  uint32
#  1   playId                  188254 non-null  uint16
#  2   nflId                   188254 non-null  uint32
#  3   pff_role                188254 non-null  category
#  4   pff_positionLinedUp     188254 non-null  category
#  5   pff_hit                 188254 non-null  int8
#  6   pff_hurry               188254 non-null  int8
#  7   pff_sack                188254 non-null  int8
#  8   pff_beatenByDefender    188254 non-null  int8
#  9   pff_hitAllowed          188254 non-null  int8
#  10  pff_hurryAllowed        188254 non-null  int8
#  11  pff_sackAllowed         188254 non-null  int8
#  12  pff_nflIdBlockedPlayer  188254 non-null  uint32
#  13  pff_blockType           47904 non-null   category
#  14  pff_backFieldBlock      188254 non-null  int8
# dtypes: category(3), int8(8), uint16(1), uint32(3)
# memory usage: 4.5 MB
